# %%
import pandas as pd
import numpy as np
from sklearn.metrics import confusion_matrix
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# Read the CSV file into a DataFrame
df = pd.read_csv('output.csv')

# Extract y_true and y_pred from the DataFrame
y_true = df['y_true']
y_pred = df['y_pred']
label = [1,2,3,4,5]

# Create the confusion matrix
cm = confusion_matrix(y_true, y_pred)

disp = ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=label)
disp.plot(xticks_rotation=45)

# %%
def normalize_confusion_matrix(confusion_matrix):
    # Compute the sum of each row
    row_sum = np.sum(confusion_matrix, axis=1, keepdims=True)
    # Divide each element in the confusion matrix by its respective row sum
    normalized_matrix = confusion_matrix / row_sum
    
    return normalized_matrix

# %%
normalized_by_row = normalize_confusion_matrix(cm)
disp = ConfusionMatrixDisplay(confusion_matrix=normalized_by_row,display_labels=label)
disp.plot(xticks_rotation=45)

# %%
# Read the CSV file into a DataFrame
df = pd.read_csv('output2.csv')

# Extract y_true and y_pred from the DataFrame
y_true = df['y_true']
y_pred = df['y_pred']
label = [1,2,3,4,5]

# Create the confusion matrix
cm = confusion_matrix(y_true, y_pred)
normalized_by_row = normalize_confusion_matrix(cm)

disp = ConfusionMatrixDisplay(confusion_matrix=normalized_by_row,display_labels=label)
disp.plot(xticks_rotation=45)
